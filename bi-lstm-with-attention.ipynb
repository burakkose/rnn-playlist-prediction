# %% [markdown]
# # Bi-directional LSTM with Attention

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode
from playlist.models.model_modes import *

ModelGenerator(mode=DatasetMode.big, model_name=ModelName.attention_bilstm).process().evaluate()
# Out:
# Epoch 00017: val_loss did not improve from 6.30612
# 135746/135746 [==============================] - 56s 411us/step
# _func: 20.74%
# _func_1: 29.83%
# _func_2: 41.46%
# _func_3: 49.85%
# _func_4: 56.38%
# _func_5: 61.69%
