# %% [markdown]
# # Bi-directional LSTM with Attention

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode
from playlist.models.model_modes import *

ModelGenerator(mode=DatasetMode.complete, model_name=ModelName.attention_bilstm).process().evaluate()
# Out:
# Epoch 00008: val_loss did not improve from 6.90422
# _func: 28.50%
# _func_1: 38.85%
# _func_2: 52.79%
# _func_3: 62.27%
# _func_4: 68.63%
# _func_5: 73.63%
