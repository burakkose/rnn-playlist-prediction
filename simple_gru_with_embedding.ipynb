# %% [markdown]
# # SimpleGRU with Embedding

# %%
from playlist.models.embedding_model_generator import EmbeddingModelGenerator
from playlist.tools.data import DatasetMode

EmbeddingModelGenerator(mode=DatasetMode.big).process().evaluate()
# Out:
# Epoch 00004: val_loss did not improve from -0.41291
# mean_absolute_error: 0.67
# mean_squared_error: 0.93
# acc: 0.19
# mean_absolute_percentage_error: 631.89
# cosine_proximity: -0.40
