# %% [markdown]
# # lstm with embedding

# %%
from playlist.models.embedding_model_generator import EmbeddingModelGenerator
from playlist.tools.data import DatasetMode
from playlist.models.model_modes import *

EmbeddingModelGenerator(mode=DatasetMode.big, model_name=ModelName.bi_directional_lstm).process().evaluate()
# Out:
# Epoch 00009: val_loss did not improve from -0.65972
# mean_absolute_error: 0.59
# mean_squared_error: 0.74
# acc: 0.26
# mean_absolute_percentage_error: 499.65
# cosine_proximity: -0.66
# categorical_crossentropy: -37.26
