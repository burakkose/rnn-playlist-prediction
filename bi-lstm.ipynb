# %% [markdown]
# # Bi-directional LSTM

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode
from playlist.models.model_modes import *

ModelGenerator(model_name=ModelName.bi_directional_lstm).process().evaluate()
# Out:
# Epoch 00019: val_loss did not improve from 5.60887
# 229658/229658 [==============================] - 42s 185us/step
# _func: 30.16%
# _func_1: 43.52%
# _func_2: 60.52%
# _func_3: 71.56%
# _func_4: 78.38%
# _func_5: 82.85%
