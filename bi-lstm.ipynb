# %% [markdown]
# # Bi-directional LSTM

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode
from playlist.models.model_modes import *

ModelGenerator(mode=DatasetMode.big, model_name=ModelName.bi_directional_lstm).process().evaluate()
# Out:
# Epoch 00016: val_loss did not improve from 6.36210
# 135746/135746 [==============================] - 52s 386us/step
# _func: 18.26%
# _func_1: 27.16%
# _func_2: 39.05%
# _func_3: 47.47%
# _func_4: 53.92%
# _func_5: 59.24%
