# %% [markdown]
# # GRU

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode

ModelGenerator().process().evaluate()
# Out:
# Epoch 00023: val_loss did not improve from 5.59521
# 229658/229658 [==============================] - 17s 76us/step
# _func: 29.64%
# _func_1: 42.83%
# _func_2: 59.58%
# _func_3: 70.79%
# _func_4: 77.60%
# _func_5: 82.07%
