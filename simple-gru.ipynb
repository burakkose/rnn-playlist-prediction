# %% [markdown]
# # GRU

# %%
from playlist.models.categorical_model_generator import ModelGenerator
from playlist.tools.data import DatasetMode

ModelGenerator(mode=DatasetMode.big).process().evaluate()
# Out:
# Epoch 00021: val_loss did not improve from 6.33835
# 135746/135746 [==============================] - 22s 160us/step
# _func: 17.55%
# _func_1: 26.16%
# _func_2: 37.59%
# _func_3: 45.82%
# _func_4: 52.10%
# _func_5: 57.11%
